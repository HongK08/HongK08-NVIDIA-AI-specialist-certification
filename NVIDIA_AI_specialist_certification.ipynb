# %% [markdown]
# # Yolo5 학습하기
# ##1. 구글 드라이브 연동

# %%
# prompt: 구글 드라이브랑 연결
from google.colab import drive
drive.flush_and_unmount()  # 기존 마운트 해제
drive.mount('/content/drive')  # 다시 마운트

# %%
# %cd /content/drive/MyDrive

# %%
# %pwd

# %% [markdown]
# # 2. Yolov5 설치

# %%
# %cd /content/drive/MyDrive/yolov5

# %%
##
#clone YOLOv5 and
# !git clone https://github.com/ultralytics/yolov5.git  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies

# %%
# !pip install Pillow==10.3

# %% [markdown]
# # 3. 이미지 파일 관리

# %%
# !mkdir -p Train/labels
# !mkdir -p Train/images
# !mkdir -p Val/labels
# !mkdir -p Val/images

# %%
##검증 데이터 만들기
import os
import shutil
from sklearn.model_selection import train_test_split

def create_validation_set(train_path, val_path, split_ratio=0.3):
    """
    Train 데이터의 일부를 Val로 이동
    """
    # 필요한 디렉토리 생성
    os.makedirs(os.path.join(val_path, 'images'), exist_ok=True)
    os.makedirs(os.path.join(val_path, 'labels'), exist_ok=True)

    # Train 이미지 리스트 가져오기
    train_images = os.listdir(os.path.join(train_path, 'images'))
    train_images = [f for f in train_images if f.endswith(('.jpg', '.jpeg', '.png'))]

    # Train/Val 분할
    _, val_images = train_test_split(train_images,
                                   test_size=split_ratio,
                                   random_state=42)

    # Val로 파일 복사
    for image_file in val_images:
        # 이미지 복사
        src_image = os.path.join(train_path, 'images', image_file)
        dst_image = os.path.join(val_path, 'images', image_file)
        shutil.copy2(src_image, dst_image)

        # 라벨 파일 복사
        label_file = os.path.splitext(image_file)[0] + '.txt'
        src_label = os.path.join(train_path, 'labels', label_file)
        dst_label = os.path.join(val_path, 'labels', label_file)
        if os.path.exists(src_label):
            shutil.copy2(src_label, dst_label)

    print(f"Created validation set with {len(val_images)} images")

# 실행
train_path = '/content/drive/MyDrive/yolov5/yolov5/Train'
val_path = '/content/drive/MyDrive/yolov5/yolov5/Val'

create_validation_set(train_path, val_path)

# %%
def check_dataset():

    train_path = '/content/drive/MyDrive/yolov5/yolov5/Train'
    val_path = '/content/drive/MyDrive/yolov5/yolov5/Val'

    # Train 데이터 확인
    train_images = len(os.listdir(os.path.join(train_path, 'images')))
    train_labels = len(os.listdir(os.path.join(train_path, 'labels')))

    # Val 데이터 확인
    val_images = len(os.listdir(os.path.join(val_path, 'images')))
    val_labels = len(os.listdir(os.path.join(val_path, 'labels')))

    print("Dataset status:")
    print(f"Train - Images: {train_images}, Labels: {train_labels}")
    print(f"Val - Images: {val_images}, Labels: {val_labels}")

# 데이터셋 상태 확인
check_dataset()

# %% [markdown]
# # 4. 학습시작

# %%
#필요 라이브러리 임포트하기
import torch
import os
from IPython.display import Image, clear_output  # to display images

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/yolov5/yolov5'

# %%
import numpy as np
import tensorflow as tf
import os
from PIL import Image
from tensorflow.python.eager.context import eager_mode

def _preproc(image, output_height=512, output_width=512, resize_side=512):
    ''' imagenet-standard: aspect-preserving resize to 256px smaller-side, then central-crop to 224px'''
    with eager_mode():
        h, w = image.shape[0], image.shape[1]
        scale = tf.cond(tf.less(h, w), lambda: resize_side / h, lambda: resize_side / w)
        resized_image = tf.compat.v1.image.resize_bilinear(tf.expand_dims(image, 0), [int(h*scale), int(w*scale)])
        cropped_image = tf.compat.v1.image.resize_with_crop_or_pad(resized_image, output_height, output_width)
        return tf.squeeze(cropped_image)

def Create_npy(imagespath, imgsize, ext) :
    images_list = [img_name for img_name in os.listdir(imagespath) if
                os.path.splitext(img_name)[1].lower() == '.'+ext.lower()]
    calib_dataset = np.zeros((len(images_list), imgsize, imgsize, 3), dtype=np.float32)

    for idx, img_name in enumerate(sorted(images_list)):
        img_path = os.path.join(imagespath, img_name)
        try:
            # 파일 크기가 정상적인지 확인
            if os.path.getsize(img_path) == 0:
                print(f"Error: {img_path} is empty.")
                continue

            img = Image.open(img_path)
            img = img.convert("RGB")  # RGBA 이미지 등 다른 형식이 있을 경우 강제로 RGB로 변환
            img_np = np.array(img)

            img_preproc = _preproc(img_np, imgsize, imgsize, imgsize)
            calib_dataset[idx,:,:,:] = img_preproc.numpy().astype(np.uint8)
            print(f"Processed image {img_path}")

        except Exception as e:
            print(f"Error processing image {img_path}: {e}")

    np.save('calib_set.npy', calib_dataset)

# %%
# "cannot identify image file" 에러가 발생하는 경우, PILLOW Version을 "!pip install Pillow==10.1" 로 변경하여 설치합니다.
Create_npy('/content/drive/MyDrive/yolov5/yolov5/Train/images', 512, 'jpg')

# %%
#모델 학습하기
# !python train.py  --img 512 --batch 16 --epochs 320 --data /content/drive/MyDrive/yolov5/yolov5/data.yaml --weights yolov5n.pt --cache

# %% [markdown]
# # 5. yolov5모델 학습 결과 검증

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5/yolov5/runs/train/exp/weights/best.pt --img 512 --conf 0.8 --source /content/drive/MyDrive/yolov5/yolov5/Train/images

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/drive/MyDrive/yolov5/yolov5/runs/detect/exp3/*.png')[:10]: #이미지 파일 형식에 맞춰 .png 또는 .jpg 등으로 수정
    display(Image(filename=imageName))
    print("\n")

# %%
# 원본 영상에서 마킹 제거 후 대조
# !python detect.py --weights /content/drive/MyDrive/yolov5/yolov5/runs/train/exp/weights/best.pt --img 512 --conf 0.7 --source /content/drive/MyDrive/Traff.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/Traff.mp4, data=data/coco128.yaml, imgsz=[512, 512], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-383-g1435a8ee Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients, 4.1 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 5 P-Cars, 51.4ms
# video 1/1 (2/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 5 P-Cars, 12.7ms
# video 1/1 (3/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 5 P-Cars, 19.6ms
# video 1/1 (4/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 5 P-Cars, 21.8ms
# video 1/1 (5/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 4 P-Cars, 14.1ms
# video 1/1 (6/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 4 P-Cars, 9.3ms
# video 1/1 (7/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 4 P-Cars, 6.8ms
# video 1/1 (8/956) /content/drive/MyDrive/Traff.mp4: 288x512 1 Pickup, 1 Bus, 4 P-Cars,
956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 10.9ms
# video 1/1 (838/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 13.0ms
# video 1/1 (839/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 10.0ms
# video 1/1 (840/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 19.9ms
# video 1/1 (841/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 14.0ms
# video 1/1 (842/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 10.7ms
# video 1/1 (843/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 2 P-Cars, 9.3ms
# video 1/1 (844/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 2 P-Cars, 9.2ms
# video 1/1 (845/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.6ms
# video 1/1 (846/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 10.1ms
# video 1/1 (847/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.1ms
# video 1/1 (848/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.3ms
# video 1/1 (849/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 3 P-Cars, 10.3ms
# video 1/1 (850/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 3 P-Cars, 16.3ms
# video 1/1 (851/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 3 P-Cars, 9.9ms
# video 1/1 (852/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 3 P-Cars, 9.2ms
# video 1/1 (853/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 3 P-Cars, 9.5ms
# video 1/1 (854/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 3 P-Cars, 11.5ms
# video 1/1 (855/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.5ms
# video 1/1 (856/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 13.3ms
# video 1/1 (857/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 15.5ms
# video 1/1 (858/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.3ms
# video 1/1 (859/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 18.6ms
# video 1/1 (860/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 25.5ms
# video 1/1 (861/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.6ms
# video 1/1 (862/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.3ms
# video 1/1 (863/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.3ms
# video 1/1 (864/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 18.7ms
# video 1/1 (865/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.1ms
# video 1/1 (866/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 23.0ms
# video 1/1 (867/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 11.8ms
# video 1/1 (868/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 22.8ms
# video 1/1 (869/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 14.8ms
# video 1/1 (870/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 15.9ms
# video 1/1 (871/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 12.0ms
# video 1/1 (872/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 21.7ms
# video 1/1 (873/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 6.9ms
# video 1/1 (874/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 8.7ms
# video 1/1 (875/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 7.4ms
# video 1/1 (876/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 14.5ms
# video 1/1 (877/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 7.3ms
# video 1/1 (878/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 10.6ms
# video 1/1 (879/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 10.3ms
# video 1/1 (880/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 9.4ms
# video 1/1 (881/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 7.1ms
# video 1/1 (882/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 12.7ms
# video 1/1 (883/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 7.2ms
# video 1/1 (884/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 9.1ms
# video 1/1 (885/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 10.5ms
# video 1/1 (886/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.0ms
# video 1/1 (887/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 11.6ms
# video 1/1 (888/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 8.2ms
# video 1/1 (889/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 7.2ms
# video 1/1 (890/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.0ms
# video 1/1 (891/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 2 P-Cars, 7.2ms
# video 1/1 (892/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 2 P-Cars, 9.0ms
# video 1/1 (893/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 2 P-Cars, 7.4ms
# video 1/1 (894/956) /content/drive/MyDrive/Traff.mp4: 288x512 4 Pickups, 2 P-Cars, 10.9ms
# video 1/1 (895/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 7.2ms
# video 1/1 (896/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.3ms
# video 1/1 (897/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 8.3ms
# video 1/1 (898/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.9ms
# video 1/1 (899/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.1ms
# video 1/1 (900/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 8.2ms
# video 1/1 (901/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 7.1ms
# video 1/1 (902/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 8.9ms
# video 1/1 (903/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 10.3ms
# video 1/1 (904/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.0ms
# video 1/1 (905/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 6.9ms
# video 1/1 (906/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.4ms
# video 1/1 (907/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 11.4ms
# video 1/1 (908/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.0ms
# video 1/1 (909/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 7.8ms
# video 1/1 (910/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.5ms
# video 1/1 (911/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 6.8ms
# video 1/1 (912/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.4ms
# video 1/1 (913/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 6.6ms
# video 1/1 (914/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 2 P-Cars, 9.9ms
# video 1/1 (915/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 6.8ms
# video 1/1 (916/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 10.1ms
# video 1/1 (917/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.2ms
# video 1/1 (918/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 7.2ms
# video 1/1 (919/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 6.8ms
# video 1/1 (920/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 9.0ms
# video 1/1 (921/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 6.6ms
# video 1/1 (922/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 9.1ms
# video 1/1 (923/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 6.9ms
# video 1/1 (924/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 9.2ms
# video 1/1 (925/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 6.6ms
# video 1/1 (926/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 4 P-Cars, 9.6ms
# video 1/1 (927/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.2ms
# video 1/1 (928/956) /content/drive/MyDrive/Traff.mp4: 288x512 3 Pickups, 3 P-Cars, 9.3ms
# video 1/1 (929/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 12.1ms
# video 1/1 (930/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 9.2ms
# video 1/1 (931/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 7.0ms
# video 1/1 (932/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 9.4ms
# video 1/1 (933/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 6.8ms
# video 1/1 (934/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 3 P-Cars, 9.0ms
# video 1/1 (935/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 7.3ms
# video 1/1 (936/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 6.5ms
# video 1/1 (937/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 9.2ms
# video 1/1 (938/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 9.1ms
# video 1/1 (939/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 7.0ms
# video 1/1 (940/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 15.1ms
# video 1/1 (941/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 8.0ms
# video 1/1 (942/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 9.1ms
# video 1/1 (943/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 7.2ms
# video 1/1 (944/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 9.0ms
# video 1/1 (945/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 7.2ms
# video 1/1 (946/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 10.4ms
# video 1/1 (947/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 7.2ms
# video 1/1 (948/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 9.4ms
# video 1/1 (949/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 7.5ms
# video 1/1 (950/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 4 P-Cars, 9.4ms
# video 1/1 (951/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 5 P-Cars, 11.1ms
# video 1/1 (952/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 5 P-Cars, 10.3ms
# video 1/1 (953/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 6 P-Cars, 7.3ms
# video 1/1 (954/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 6 P-Cars, 10.0ms
# video 1/1 (955/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 6 P-Cars, 8.8ms
# video 1/1 (956/956) /content/drive/MyDrive/Traff.mp4: 288x512 2 Pickups, 6 P-Cars, 7.0ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.4ms NMS per image at shape (1, 3, 512, 512)
# Results saved to runs/detect/exp4

# %%
# 새 영상에서 마킹 제거 후 대조
# !python detect.py --weights /content/drive/MyDrive/yolov5/yolov5/runs/train/exp/weights/best.pt --img 512 --conf 0.83 --source /content/drive/MyDrive/MAIN_TF.mp4
